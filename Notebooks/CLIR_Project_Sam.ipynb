# %% [markdown]
# # Cross-Language Information Retrieval (CLIR)
#
# ### Course
# MEL24 - Multilingual Information Retrieval
#
# ### Project
#
# Multilingual Semantic Search over an English Amazon Product Catalog using Sentence Transformers.
#
# ### Model
#
# sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2
#
# ### Dataset
#
# Amazon Product Dataset (Kaggle)

# %%
# ============================================================
# Install Required Libraries
# ============================================================

# !pip -q install kagglehub[pandas-datasets]
# !pip -q install sentence-transformers
# !pip -q install scikit-learn
# !pip -q install seaborn

# %%
# ============================================================
# Import Required Libraries
# ============================================================

import os
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

import kagglehub
from kagglehub import KaggleDatasetAdapter

from sentence_transformers import SentenceTransformer

from sklearn.metrics.pairwise import cosine_similarity

# %%
import os

# %%
# ============================================================
# Download the Amazon Product Dataset from Kaggle
# ============================================================

import kagglehub

dataset_path = kagglehub.dataset_download(
    "piyushjain16/amazon-product-data"
)

print("Dataset downloaded successfully!")
print("Dataset location:", dataset_path)
# Out:
# ...
# 100%|██████████| 646M/646M [00:06<00:00, 99.1MB/s]
# Extracting files...
# Dataset downloaded successfully!
# Dataset location: /root/.cache/kagglehub/datasets/piyushjain16/amazon-product-data/versions/3

# %%
import kagglehub

# %%
dataset_path = kagglehub.dataset_download(
    "piyushjain16/amazon-product-data"
)
# Out:
# Using Colab cache for faster access to the 'amazon-product-data' dataset.

# %%
# ============================================================
# Display all files in the downloaded dataset
# ============================================================

import os

print("Dataset Location:")
print(dataset_path)

print("\nFiles in the dataset:\n")

for root, dirs, files in os.walk(dataset_path):
    for file in files:
        print(os.path.join(root, file))
# Out:
# Dataset Location:
# /kaggle/input/amazon-product-data
#
# Files in the dataset:
#
# /kaggle/input/amazon-product-data/dataset/train.csv

# %%
import pandas as pd

# Load the Amazon Product Dataset
df = pd.read_csv("/kaggle/input/amazon-product-data/dataset/train.csv")

# Show the first 5 rows
df.head()

# %%
df = pd.read_csv(...)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6048/2307056283.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(...)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# ...
